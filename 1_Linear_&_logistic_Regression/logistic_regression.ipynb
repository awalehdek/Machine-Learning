# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("covid_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='*',color='purple')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)
X_test
# Out:
#     age
# 1    25
# 13   29
# 23   45
# 9    61
# 17   58
# 5    56

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.83917809, 0.16082191],
#        [0.76705644, 0.23294356],
#        [0.34306152, 0.65693848],
#        [0.07648267, 0.92351733],
#        [0.10471925, 0.89528075],
#        [0.12834477, 0.87165523]])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([0, 0, 1, 1, 1, 1])

# %%
X_test
# Out:
#     age
# 1    25
# 13   29
# 23   45
# 9    61
# 17   58
# 5    56

# %% [markdown]
# ## Implementing Sigmoid Function

# %% [markdown]
# ![Sigmoid_Function.png](attachment:f9b0b348-7c7d-4900-ad14-5be5b33e29af.png)

# %%
import math 
def sigmoid(x):
    return 1/(1+ math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -1.53
    y = sigmoid(z)
    return y

# %%
age = 20
prediction_function(age)
# Out:
# 0.3340330732481797

# %% [markdown]
# The prediction function is 0.334 < 0.5 mean at someone at age 20 will not have insurance
#
# ![sigmoid_graph.png](attachment:3fff64f1-ffaf-4643-9701-62f4e671f82f.png)
